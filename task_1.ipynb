# %% [markdown]
# # COMPUTER VISION AND PATTERN RECOGNITION PROJECT
# ## Task 1
# ## Alessandro Cesa

# %% [markdown]
# This Notebook contains the code for the task 1 of the project.
#
# At first the necessary libraries have to be imported.

# %%
import torch.optim as optim
from torch.utils.data import DataLoader,ConcatDataset
from torchvision.datasets import ImageFolder

# %%
#Adjust according to your path
import sys
sys.path.append('/orfeo/cephfs/home/dssc/acesa000/Computer_Vision_Project_Cesa/functions') #Adjust according to your path

from image_handling_functions import *
from train_test_functions import *
from neural_networks import *

# %% [markdown]
# Then we'll load the dataset

# %%
# %%capture 
#Run if you don't already have the dataset
"""
# !git clone https://github.com/AlessandroCesaTs/Computer_Vision_Project_Cesa.git
"""

# %%
#Adjust according to your path
train_path = "/orfeo/cephfs/home/dssc/acesa000/Computer_Vision_Project_Cesa/CVPR2023_project_2_and_3_data/train"
test_path = "/orfeo/cephfs/home/dssc/acesa000/Computer_Vision_Project_Cesa/CVPR2023_project_2_and_3_data/test"

# %% [markdown]
# We get the device (CPU or GPU)

# %%
device = get_default_device()

# %% [markdown]
# Set the seeds for reproducibility

# %%
np.random.seed(123)
torch.manual_seed(123)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
if device.type == 'cuda':
    torch.cuda.empty_cache()

# %% [markdown]
# The data sets have to be transformed, using the ImageFolder function

# %%
train=ImageFolder(root=train_path,transform=resize_transformation)
test=ImageFolder(root=test_path,transform=resize_transformation)

# %% [markdown]
# We can check the size of the dataset and check the first image

# %%
# %%capture
"""
print(f"Train size: {len(train)}")
print(f"Test size: {len(test)}")
print(train.classes)
"""

# %%
# %%capture
"""
index=1
img,label=train[index]

print(f"label: {label}")

print("class: " + train.classes[label])
# display
figure = plt.figure()
plt.imshow(img.numpy().transpose((1, 2, 0)),cmap='gray') #<< swap axes because img is (3,H,W) but imshow() expects (H,W,3)
"""

# %% [markdown]
# Split training set into training and validation

# %%
train_size=int(0.85*len(train))
validation_size=len(train)-train_size
training_set,validation_set=torch.utils.data.random_split(train,[train_size,validation_size])

# %% [markdown]
# We'll now create the Data Loaders, which are basically objects that make easy to iterate through the data by batches; and we'll transfer them to the GPU if available.

# %%
batch_size = 32
train_loader = DataLoader(training_set, batch_size=batch_size,shuffle=True,pin_memory=True)
validation_loader = DataLoader(validation_set, batch_size=batch_size,shuffle=False,pin_memory=True)
test_loader = DataLoader(test, batch_size=batch_size,shuffle=False,pin_memory=True)

# %%
train_loader = DeviceDataLoader(train_loader, device)
validation_loader = DeviceDataLoader(validation_loader, device)
test_loader = DeviceDataLoader(test_loader, device)

# %% [markdown]
# We can check the Data Loaders and a batch of data

# %%
# %%capture
"""
for X, y in test_loader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
"""

# %%
# %%capture
"""
classes=train.classes

# get a batch from the training set
dataiter = iter(train_loader)
images, labels = next(dataiter)   #images is a (batch_size,3,32,32) tensor

print(images.size())

img=torchvision.utils.make_grid(images)
figure = plt.figure()
plt.imshow(img.cpu().numpy().transpose((1, 2, 0)).astype(np.uint8),cmap='gray') #<< swap axes because img is (3,H,W) but imshow() expects (H,W,3)

print(' '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))
"""

# %% [markdown]
# We can now instantiate, train and test the model

# %%
model = simpleCNN().to(device)
model.apply(init_weights)
loss_function=nn.CrossEntropyLoss()
optimizer=optim.SGD(model.parameters(),lr=0.0004,momentum=0.9)
# Print the model summary
#print(model)
# Out:
# simpleCNN(
#   (conv1): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1))
#   (relu1): ReLU()
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (relu2): ReLU()
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (relu3): ReLU()
#   (fc1): Linear(in_features=4608, out_features=15, bias=True)
# )

# %%
model_path=train_model(model,train_loader,validation_loader,loss_function,optimizer,50,device)
# Out:
# EPOCH1:
# LOSS train: 2.7080834686756132 validation: 2.709959030151367 | validation_accuracy: 6.222222222222222%
# EPOCH2:
# LOSS train: 2.707673192024231 validation: 2.7109193801879883 | validation_accuracy: 5.777777777777778%
# EPOCH3:
# LOSS train: 2.7074856042861937 validation: 2.711177110671997 | validation_accuracy: 5.777777777777778%
# EPOCH4:
# LOSS train: 2.7069859385490416 validation: 2.713294744491577 | validation_accuracy: 5.777777777777778%
# EPOCH5:
# LOSS train: 2.705793434381485 validation: 2.7124738693237305 | validation_accuracy: 5.777777777777778%
# EPOCH6:
# LOSS train: 2.7036907613277434 validation: 2.712118625640869 | validation_accuracy: 6.222222222222222%
# EPOCH7:
# LOSS train: 2.7025950729846953 validation: 2.704118251800537 | validation_accuracy: 7.111111111111111%
# EPOCH8:
# LOSS train: 2.694780695438385 validation: 2.697244882583618 | validation_accuracy: 9.333333333333334%
# EPOCH9:
# LOSS train: 2.6768413901329042 validation: 2.6328015327453613 | validation_accuracy: 8.88888888888889%
# EPOCH10:
# LOSS train: 2.6449463844299315 validation: 2.525641441345215 | validation_accuracy: 14.222222222222221%
# EPOCH11:
# LOSS train: 2.611755448579788 validation: 2.59940505027771 | validation_accuracy: 12.88888888888889%
# EPOCH12:
# LOSS train: 2.6019713938236237 validation: 2.520888566970825 | validation_accuracy: 14.222222222222221%
# EPOCH13:
# LOSS train: 2.515994703769684 validation: 2.561276912689209 | validation_accuracy: 12.444444444444445%
# EPOCH14:
# LOSS train: 2.481495237350464 validation: 2.5301432609558105 | validation_accuracy: 18.22222222222222%
# EPOCH15:
# LOSS train: 2.4367389261722563 validation: 2.4677741527557373 | validation_accuracy: 14.222222222222221%
# EPOCH16:
# LOSS train: 2.3478395700454713 validation: 2.370034694671631 | validation_accuracy: 19.11111111111111%
# EPOCH17:
# LOSS train: 2.29377144575119 validation: 2.510824203491211 | validation_accuracy: 17.333333333333332%
# EPOCH18:
# LOSS train: 2.217364239692688 validation: 2.2903037071228027 | validation_accuracy: 19.11111111111111%
# EPOCH19:
# LOSS train: 2.1728040516376494 validation: 2.2579972743988037 | validation_accuracy: 21.333333333333332%
# EPOCH20:
# LOSS train: 1.9787797957658768 validation: 2.257192611694336 | validation_accuracy: 20.444444444444443%
# EPOCH21:
# LOSS train: 1.8867159336805344 validation: 2.2160027027130127 | validation_accuracy: 26.666666666666668%
# EPOCH22:
# LOSS train: 1.694442829489708 validation: 2.123831272125244 | validation_accuracy: 28.444444444444443%
# EPOCH23:
# LOSS train: 1.557122740149498 validation: 2.039750099182129 | validation_accuracy: 29.333333333333332%
# EPOCH24:
# LOSS train: 1.3971877902746201 validation: 2.162776470184326 | validation_accuracy: 27.555555555555557%
# EPOCH25:
# LOSS train: 1.3340047866106033 validation: 2.415736436843872 | validation_accuracy: 28.0%
# EPOCH26:
# LOSS train: 1.2348277017474174 validation: 2.4453604221343994 | validation_accuracy: 26.22222222222222%
# EPOCH27:
# LOSS train: 1.1773582383990289 validation: 2.7328624725341797 | validation_accuracy: 21.333333333333332%
# EPOCH28:
# LOSS train: 1.1927560597658158 validation: 2.996825695037842 | validation_accuracy: 24.444444444444443%
# EPOCH29:
# LOSS train: 0.9028169587254524 validation: 3.6049413681030273 | validation_accuracy: 25.333333333333332%
# EPOCH30:
# LOSS train: 0.7121276333928108 validation: 4.177619457244873 | validation_accuracy: 24.88888888888889%
# EPOCH31:
# LOSS train: 0.6256979994475842 validation: 4.209244251251221 | validation_accuracy: 23.555555555555557%
# EPOCH32:
# LOSS train: 0.6149423368275165 validation: 4.197653293609619 | validation_accuracy: 24.0%
# EPOCH33:
# LOSS train: 0.37120707929134367 validation: 5.1615495681762695 | validation_accuracy: 24.444444444444443%
# EPOCH34:
# LOSS train: 0.2553419666364789 validation: 5.63437557220459 | validation_accuracy: 27.11111111111111%
# EPOCH35:
# LOSS train: 0.21913999011740087 validation: 6.2493977546691895 | validation_accuracy: 24.444444444444443%
# EPOCH36:
# LOSS train: 0.2818359263706952 validation: 5.7932209968566895 | validation_accuracy: 26.666666666666668%
# EPOCH37:
# LOSS train: 0.22664257436990737 validation: 6.999058246612549 | validation_accuracy: 27.555555555555557%
# EPOCH38:
# LOSS train: 0.17672150526195765 validation: 8.216779708862305 | validation_accuracy: 26.22222222222222%
# EPOCH39:
# LOSS train: 0.25060894191265104 validation: 9.284831047058105 | validation_accuracy: 25.333333333333332%
# EPOCH40:
# LOSS train: 0.1321970715885982 validation: 8.424139976501465 | validation_accuracy: 28.444444444444443%
# EPOCH41:
# LOSS train: 0.06783602044451982 validation: 9.574564933776855 | validation_accuracy: 24.88888888888889%
# EPOCH42:
# LOSS train: 0.0450022334465757 validation: 10.22468090057373 | validation_accuracy: 23.555555555555557%
# EPOCH43:
# LOSS train: 0.028407759300898762 validation: 10.592723846435547 | validation_accuracy: 24.0%
# EPOCH44:
# LOSS train: 0.014304426818853244 validation: 10.765456199645996 | validation_accuracy: 24.88888888888889%
# EPOCH45:
# LOSS train: 0.0073282610421301795 validation: 11.002378463745117 | validation_accuracy: 23.555555555555557%
# EPOCH46:
# LOSS train: 0.005406866565317614 validation: 11.02418041229248 | validation_accuracy: 24.444444444444443%
# EPOCH47:
# LOSS train: 0.012165176745475037 validation: 11.076091766357422 | validation_accuracy: 23.555555555555557%
# EPOCH48:
# LOSS train: 0.013538200667244382 validation: 11.665705680847168 | validation_accuracy: 23.555555555555557%
# EPOCH49:
# LOSS train: 0.01652707002212992 validation: 11.433115005493164 | validation_accuracy: 24.0%
# EPOCH50:
# LOSS train: 0.01684318314655684 validation: 11.222671508789062 | validation_accuracy: 23.555555555555557%
# Time: 173.52932906150818

# %%
test_model(simpleCNN(),model_path,test_loader,test,device)
# Out:
# Accuracy of the network on the test images: 29.31323283082077%

# %%
# !rm model*
